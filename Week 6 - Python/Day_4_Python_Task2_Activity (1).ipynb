# %% [markdown]
# # Pandas, Matplotlib and Seaborn

# %%
import pandas as pd

# %% [markdown]
# [Dataset Soruce](https://www.kaggle.com/datasets/rajkumarpandey02/gdp-in-usd-per-capita-income-by-country)

# %% [markdown]
# CONTENT
# <p>The figures presented here do not take into account differences in the cost of living in different countries, and the results vary greatly from one year to another based on fluctuations in the exchange rates of the country's currency. Such fluctuations change a country's ranking from one year to the next, even though they often make little or no difference to the standard of living of its population.
#
# GDP per capita is often considered an indicator of a country's standard of living; however, this is inaccurate because GDP per capita is not a measure of personal income.
#
# Comparisons of national income are also frequently made on the basis of purchasing power parity (PPP), to adjust for differences in the cost of living in different countries. (See List of countries by GDP (PPP) per capita.) PPP largely removes the exchange rate problem but not others; it does not reflect the value of economic output in international trade, and it also requires more estimation than GDP per capita. On the whole, PPP per capita figures are more narrowly spread than nominal GDP per capita figures.</p>

# %% [markdown]
# Here are some resources to learn about GDP:
# #### [World Bank](https://data.worldbank.org/indicator/ny.gdp.pcap.cd?most_recent_value_desc=false)
# #### [Our World in Data](https://ourworldindata.org/grapher/gdp-per-capita-worldbank)
# #### [IMF](https://www.imf.org/external/datamapper/NGDPD@WEO/OEMDC/ADVEC/WEOWORLD)
# #### [UN Data](https://data.un.org/Data.aspx?d=SNAAMA&f=grID%3A101%3BcurrID%3AUSD%3BpcFlag%3A1)

# %%
df = pd.read_csv("GDP (nominal) per Capita.csv",encoding= 'unicode_escape',  index_col=0)

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Use this section to explore and inspect dataset.

# %%
# number of countries per region
region_counts = df['UN_Region'].value_counts().reset_index()
region_counts.columns = ['Region', 'Number of Countries']
print(region_counts)
# Out:
#      Region  Number of Countries
# 0    Africa                   55
# 1      Asia                   51
# 2  Americas                   48
# 3    Europe                   48
# 4   Oceania                   20
# 5     World                    1

# %%
#What is European Union[n 1]?
eu_row = df[df['Country/Territory'].str.contains('European Union')]
print(eu_row.to_string(index=False))
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# European Union[n 1]    Europe         39940      2023               38411            2021        31875    2021

# %%
# Countries in Europe below average
europe_countries = df[(df['UN_Region'] == 'Europe') &
                      (~df['Country/Territory'].str.contains('European Union', na=False))]
europe_avg_gdp = europe_countries['IMF_Estimate'].mean()
below_avg = europe_countries[europe_countries['IMF_Estimate'] < europe_avg_gdp]
below_avg_sorted = below_avg.sort_values('IMF_Estimate')
print(f"European average GDP per capita (IMF 2023): ${europe_avg_gdp:,.2f}\n")
print("European countries below average:")
print(below_avg_sorted[['Country/Territory', 'IMF_Estimate']].to_string(index=False))
# Out:
# European average GDP per capita (IMF 2023): $34,329.87
#
# European countries below average:
#      Country/Territory  IMF_Estimate
#                 Monaco             0
#          Liechtenstein             0
#            Isle of Man             0
#        Channel Islands             0
#          Faroe Islands             0
#                Ukraine          4654
#                 Kosovo          5641
#                Moldova          6342
#                Albania          7058
#        North Macedonia          7384
#                Belarus          7944
# Bosnia and Herzegovina          8223
#                 Serbia         10849
#             Montenegro         11289
#                 Russia         14403
#               Bulgaria         14893
#                Romania         18530
#                Hungary         19385
#                 Poland         19912
#                Croatia         20537
#                 Greece         22595
#               Slovakia         23457
#                 Latvia         25136
#               Portugal         26012
#              Lithuania         28094
#                Estonia         31209
#                  Spain         31223
#         Czech Republic         31368
#               Slovenia         32214

# %%
# Which countries in Europe has higher GDP than UK?
uk_gdp = df[df['Country/Territory'] == 'United Kingdom']['IMF_Estimate'].values[0]
europe_countries = df[(df['UN_Region'] == 'Europe') &
                      (~df['Country/Territory'].str.contains('European Union', na=False))]
higher_than_uk = europe_countries[europe_countries['IMF_Estimate'] > uk_gdp]
higher_than_uk_sorted = higher_than_uk.sort_values('IMF_Estimate', ascending=False)

print(f"UK GDP per capita (IMF 2023): ${uk_gdp:,.2f}\n")
print("European countries with higher GDP per capita than the UK:")
print(higher_than_uk_sorted[['Country/Territory', 'IMF_Estimate']].to_string(index=False))
# Out:
# UK GDP per capita (IMF 2023): $46,371.00
#
# European countries with higher GDP per capita than the UK:
# Country/Territory  IMF_Estimate
#        Luxembourg        132372
#           Ireland        114581
#            Norway        101103
#       Switzerland         98767
#           Iceland         75180
#           Denmark         68827
#       Netherlands         61098
#           Austria         56802
#            Sweden         55395
#           Finland         54351
#           Belgium         53377
#        San Marino         52949
#           Germany         51383

# %% [markdown]
# ## groupby()

# %% [markdown]
# [Learn more about groupby](https://www.geeksforgeeks.org/pandas-groupby/)

# %%
grouped = df.groupby('UN_Region')['IMF_Estimate'].mean().reset_index()
rounded_grouped =grouped.round(2)
print(rounded_grouped)
# Out:
#   UN_Region  IMF_Estimate
# 0    Africa       2802.35
# 1  Americas      11871.04
# 2      Asia      16665.25
# 3    Europe      34446.75
# 4   Oceania       9133.15
# 5     World      13440.00

# %% [markdown]
# ## Which countries below average by IMF world estimate?

# %%
#Step 1: Get world average GDP (IMF 2023 estimate)
world_avg = df[df['Country/Territory'] == 'World']['IMF_Estimate'].values[0]

# Step 2: Filter countries (exclude regions and world aggregate)
countries = df[(df['Country/Territory'] != 'World') &
               (~df['UN_Region'].isin(['World'])) &
               (~df['Country/Territory'].str.contains('European Union', na=False))]
 # Step 3: Find countries below world average
below_avg = countries[countries['IMF_Estimate'] < world_avg]

# Sort results by GDP (ascending)
below_avg_sorted = below_avg.sort_values('IMF_Estimate')

# Display results
print(f"World average GDP per capita (IMF 2023): ${world_avg:,.2f}\n")
print(f"Number of countries below average: {len(below_avg_sorted)}\n")
print("Countries below world average GDP:")
print(below_avg_sorted[['Country/Territory', 'UN_Region', 'IMF_Estimate']].to_string(index=True))
# Out:
# World average GDP per capita (IMF 2023): $13,440.00
#
# Number of countries below average: 152
#
# Countries below world average GDP:
#                     Country/Territory UN_Region  IMF_Estimate
# 1                              Monaco    Europe             0
# 2                       Liechtenstein    Europe             0
# 5                             Bermuda  Americas             0
# 9                         Isle of Man    Europe             0
# 10                     Cayman Islands  Americas             0
# 14                    Channel Islands    Europe             0
# 15                      Faroe Islands    Europe             0
# 19                          Greenland  Americas             0
# 31             British Virgin Islands  Americas             0
# 37                  US Virgin Islands  Americas             0
# 39                      New Caledonia   Oceania             0
# 42                               Guam   Oceania             0
# 58          Sint Maarten (Dutch part)  Americas             0
# 61           Northern Mariana Islands   Oceania             0
# 65         Saint Martin (French part)  Americas             0
# 68           Turks and Caicos Islands  Americas             0
# 71                   French Polynesia   Oceania             0
# 76                       Cook Islands   Oceania             0
# 77                           Anguilla  Americas             0
# 82                           CuraÃ§ao  Americas             0
# 85                         Montserrat  Americas             0
# 86                     American Samoa   Oceania             0
# 104                              Cuba  Americas             0
# 196                          Zanzibar    Africa             0
# 212                       North Korea      Asia             0
# 204                             Syria      Asia             0
# 223                           Burundi    Africa           249
# 221                      Sierra Leone    Africa           415
# 220                       South Sudan    Africa           467
# 219                            Malawi    Africa           496
# 218          Central African Republic    Africa           534
# 217                        Madagascar    Africa           536
# 216                           Somalia    Africa           544
# 215                             Yemen      Asia           573
# 214                        Mozambique    Africa           587
# 222                       Afghanistan      Asia           611
# 213                             Niger    Africa           613
# 211                              Chad    Africa           667
# 210                          DR Congo    Africa           695
# 209                           Eritrea    Africa           715
# 208                           Liberia    Africa           805
# 207                            Gambia    Africa           861
# 206                              Mali    Africa           889
# 205                      Burkina Faso    Africa           900
# 203                            Rwanda    Africa           970
# 202                     Guinea-Bissau    Africa           974
# 201                             Sudan    Africa           975
# 200                              Togo    Africa           990
# 199                            Uganda    Africa          1105
# 198                           Myanmar      Asia          1180
# 197                           Lesotho    Africa          1208
# 195                        Tajikistan      Asia          1277
# 194                          Tanzania    Africa          1348
# 193                           Comoros    Africa          1360
# 192                             Nepal      Asia          1377
# 191                             Benin    Africa          1390
# 190                            Zambia    Africa          1423
# 189                       Timor-Leste      Asia          1425
# 188                          Ethiopia    Africa          1475
# 187                            Guinea    Africa          1549
# 186                          Pakistan      Asia          1658
# 185                          Cameroon    Africa          1699
# 184                           Senegal    Africa          1719
# 183                        Kyrgyzstan      Asia          1736
# 182                          Zimbabwe    Africa          1851
# 181                              Laos      Asia          1858
# 180                          Cambodia      Asia          1896
# 179                          Kiribati   Oceania          1989
# 178                             Ghana    Africa          2024
# 177                             Haiti  Americas          2173
# 176                             Kenya    Africa          2269
# 175                           Nigeria    Africa          2280
# 174                   Solomon Islands   Oceania          2299
# 173                        Bangladesh      Asia          2469
# 172                        Mauritania    Africa          2475
# 171                        Uzbekistan      Asia          2563
# 170                             Congo    Africa          2584
# 169                         Nicaragua  Americas          2589
# 168                             India      Asia          2601
# 167                       Ivory Coast    Africa          2646
# 166          SÃ£o TomÃ© and PrÃ­ncipe    Africa          2695
# 165                           Vanuatu   Oceania          3188
# 164                            Angola    Africa          3204
# 163                          Honduras  Americas          3278
# 162                         Sri Lanka      Asia          3362
# 161                            Bhutan      Asia          3497
# 160                         Palestine      Asia          3506
# 159                  Papua New Guinea   Oceania          3517
# 151                           Lebanon      Asia          3589
# 158                         Venezuela  Americas          3640
# 157                             Egypt    Africa          3644
# 156                           Morocco    Africa          3748
# 155                           Bolivia  Americas          3800
# 154                          Djibouti    Africa          3802
# 153                       Philippines      Asia          3905
# 152                           Tunisia    Africa          4071
# 150                          Eswatini    Africa          4146
# 149                              Iran      Asia          4251
# 148                        Cape Verde    Africa          4278
# 147                        Micronesia   Oceania          4336
# 146                             Samoa   Oceania          4436
# 145                           Vietnam      Asia          4475
# 144                           Algeria    Africa          4481
# 143                           Ukraine    Europe          4654
# 142                          Mongolia      Asia          4814
# 141                         Indonesia      Asia          5016
# 140                            Jordan      Asia          5048
# 139                           Namibia    Africa          5100
# 138                  Marshall Islands   Oceania          5164
# 137                       El Salvador  Americas          5308
# 136                         Guatemala  Americas          5358
# 135                             Tonga   Oceania          5421
# 134                          Suriname  Americas          5556
# 133                            Kosovo    Europe          5641
# 132                          Paraguay  Americas          5667
# 131                              Fiji   Oceania          5887
# 130                            Tuvalu   Oceania          6007
# 129                              Iraq      Asia          6180
# 128                           Jamaica  Americas          6282
# 127                           Moldova    Europe          6342
# 126                          Colombia  Americas          6417
# 125                      South Africa    Africa          6485
# 124                           Ecuador  Americas          6642
# 123                        Azerbaijan      Asia          6757
# 122                             Libya    Africa          6763
# 121                            Belize  Americas          7017
# 120                           Albania    Europe          7058
# 119                          Botswana    Africa          7270
# 118                   North Macedonia    Europe          7384
# 117                           Georgia      Asia          7600
# 116                              Peru  Americas          7772
# 115                           Belarus    Europe          7944
# 114                           Armenia      Asia          8007
# 113                          Thailand      Asia          8181
# 112            Bosnia and Herzegovina    Europe          8223
# 111                          Dominica  Americas          9144
# 110                             Gabon    Africa          9294
# 109  Saint Vincent and the Grenadines  Americas          9359
# 108                            Brazil  Americas          9673
# 107                 Equatorial Guinea    Africa          9777
# 106                            Serbia    Europe         10849
# 105                           Grenada  Americas         11137
# 103                        Montenegro    Europe         11289
# 102                Dominican Republic  Americas         11308
# 101                         Mauritius    Africa         11548
# 100                             Nauru   Oceania         11825
# 99                             Turkey      Asia         11931
# 98                        Saint Lucia  Americas         12264
# 97                         Kazakhstan      Asia         12306
# 96                             Mexico  Americas         12673
# 95                       Turkmenistan      Asia         13065
# 94                           Malaysia      Asia         13382

# %% [markdown]
# ### IMF estimate 0 values

# %%
# Find rows where IMF_Estimate is 0 or NaN
zero_or_missing = df[(df['IMF_Estimate'] == 0) | (df['IMF_Estimate'].isna())]

# Display results
print(f"Countries with IMF Estimate = 0 or missing ({len(zero_or_missing)} found):")
print(zero_or_missing[['Country/Territory', 'UN_Region', 'IMF_Estimate']].to_string(index=False))
# Out:
# Countries with IMF Estimate = 0 or missing (26 found):
#          Country/Territory UN_Region  IMF_Estimate
#                     Monaco    Europe             0
#              Liechtenstein    Europe             0
#                    Bermuda  Americas             0
#                Isle of Man    Europe             0
#             Cayman Islands  Americas             0
#            Channel Islands    Europe             0
#              Faroe Islands    Europe             0
#                  Greenland  Americas             0
#     British Virgin Islands  Americas             0
#          US Virgin Islands  Americas             0
#              New Caledonia   Oceania             0
#                       Guam   Oceania             0
#  Sint Maarten (Dutch part)  Americas             0
#   Northern Mariana Islands   Oceania             0
# Saint Martin (French part)  Americas             0
#   Turks and Caicos Islands  Americas             0
#           French Polynesia   Oceania             0
#               Cook Islands   Oceania             0
#                   Anguilla  Americas             0
#                   CuraÃ§ao  Americas             0
#                 Montserrat  Americas             0
#             American Samoa   Oceania             0
#                       Cuba  Americas             0
#                   Zanzibar    Africa             0
#                      Syria      Asia             0
#                North Korea      Asia             0

# %% [markdown]
# ## Which country has highest UN Estimate?

# %%
# Find country with the highest UN Estimate
highest_un_estimate = df[df['UN_Estimate'] == df['UN_Estimate'].max()]

# Display the results
print(highest_un_estimate[['Country/Territory', 'UN_Region', 'UN_Estimate']].to_string(index=False))
# Out:
# Country/Territory UN_Region  UN_Estimate
#            Monaco    Europe       234317

# %% [markdown]
# ## Which country has highest Worlbank Estimate?

# %%
# Which conntry has the highest Workbank Estimate?
highest_wb_estimate = df[df['WorldBank_Estimate'] == df['WorldBank_Estimate'].max()]

# Display the results
print(highest_wb_estimate[['Country/Territory', 'UN_Region', 'WorldBank_Estimate']].to_string(index=False))
# Out:
# Country/Territory UN_Region  WorldBank_Estimate
#            Monaco    Europe              234316

# %% [markdown]
# ## Which country has highest IMF Estimate?

# %%
# Which country has highest IMF Estimate?
highest_imf_estimate = df[df['IMF_Estimate'] == df['IMF_Estimate'].max()]

# Display the results
print(highest_imf_estimate[['Country/Territory', 'UN_Region', 'IMF_Estimate']].to_string(index=False))
# Out:
# Country/Territory UN_Region  IMF_Estimate
#        Luxembourg    Europe        132372

# %% [markdown]
# ## Filling 0 Values by average

# %%
import numpy as np

# %%
# replace 0 with null values
df['IMF_Estimate'] = df['IMF_Estimate'].replace(0, np.nan)

# Display the results
print(df[['Country/Territory', 'UN_Region', 'IMF_Estimate']].to_string(index=False))
# Out:
#                Country/Territory UN_Region  IMF_Estimate
#                           Monaco    Europe           NaN
#                    Liechtenstein    Europe           NaN
#                       Luxembourg    Europe      132372.0
#                          Ireland    Europe      114581.0
#                          Bermuda  Americas           NaN
#                           Norway    Europe      101103.0
#                      Switzerland    Europe       98767.0
#                        Singapore      Asia       91100.0
#                      Isle of Man    Europe           NaN
#                   Cayman Islands  Americas           NaN
#                            Qatar      Asia       83891.0
#                    United States  Americas       80034.0
#                          Iceland    Europe       75180.0
#                  Channel Islands    Europe           NaN
#                    Faroe Islands    Europe           NaN
#                          Denmark    Europe       68827.0
#                        Australia   Oceania       64964.0
#                      Netherlands    Europe       61098.0
#                        Greenland  Americas           NaN
#                          Austria    Europe       56802.0
#                           Israel      Asia       55535.0
#                           Sweden    Europe       55395.0
#                          Finland    Europe       54351.0
#                          Belgium    Europe       53377.0
#                       San Marino    Europe       52949.0
#                           Canada  Americas       52722.0
#                        Hong Kong      Asia       52429.0
#                          Germany    Europe       51383.0
#                            Macau      Asia       50571.0
#             United Arab Emirates      Asia       49451.0
#           British Virgin Islands  Americas           NaN
#                      New Zealand   Oceania       48826.0
#                   United Kingdom    Europe       46371.0
#                           France    Europe       44408.0
#                          Andorra    Europe       44387.0
#              European Union[n 1]    Europe       39940.0
#                US Virgin Islands  Americas           NaN
#                      Puerto Rico  Americas       38567.0
#                    New Caledonia   Oceania           NaN
#                            Malta    Europe       36989.0
#                            Italy    Europe       36812.0
#                             Guam   Oceania           NaN
#                          Bahamas  Americas       35458.0
#                            Japan      Asia       35385.0
#                           Brunei      Asia       35103.0
#                           Taiwan      Asia       33907.0
#                           Cyprus      Asia       33807.0
#                           Kuwait      Asia       33646.0
#                      South Korea      Asia       33393.0
#                            Aruba  Americas       33094.0
#                         Slovenia    Europe       32214.0
#                   Czech Republic    Europe       31368.0
#                            Spain    Europe       31223.0
#                          Estonia    Europe       31209.0
#                     Saudi Arabia      Asia       29922.0
#                          Bahrain      Asia       28385.0
#                        Lithuania    Europe       28094.0
#        Sint Maarten (Dutch part)  Americas           NaN
#                         Portugal    Europe       26012.0
#                           Latvia    Europe       25136.0
#         Northern Mariana Islands   Oceania           NaN
#                         Slovakia    Europe       23457.0
#                           Greece    Europe       22595.0
#                             Oman      Asia       21960.0
#       Saint Martin (French part)  Americas           NaN
#                          Uruguay  Americas       21677.0
#                         Barbados  Americas       21085.0
#         Turks and Caicos Islands  Americas           NaN
#                           Guyana  Americas       20539.0
#                          Croatia    Europe       20537.0
#                 French Polynesia   Oceania           NaN
#                           Poland    Europe       19912.0
#              Trinidad and Tobago  Americas       19858.0
#                       Seychelles    Africa       19536.0
#                          Hungary    Europe       19385.0
#                     Cook Islands   Oceania           NaN
#                         Anguilla  Americas           NaN
#                          Romania    Europe       18530.0
#              Antigua and Barbuda  Americas       18244.0
#            Saint Kitts and Nevis  Americas       17856.0
#                            Chile  Americas       17827.0
#                         CuraÃ§ao  Americas           NaN
#                         Maldives      Asia       17626.0
#                           Panama  Americas       17350.0
#                       Montserrat  Americas           NaN
#                   American Samoa   Oceania           NaN
#                         Bulgaria    Europe       14893.0
#                            Palau   Oceania       14804.0
#                       Costa Rica  Americas       14733.0
#                           Russia    Europe       14403.0
#                            China      Asia       13721.0
#                        Argentina  Americas       13709.0
#                            World     World       13440.0
#                         Malaysia      Asia       13382.0
#                     Turkmenistan      Asia       13065.0
#                           Mexico  Americas       12673.0
#                       Kazakhstan      Asia       12306.0
#                      Saint Lucia  Americas       12264.0
#                           Turkey      Asia       11931.0
#                            Nauru   Oceania       11825.0
#                        Mauritius    Africa       11548.0
#               Dominican Republic  Americas       11308.0
#                       Montenegro    Europe       11289.0
#                             Cuba  Americas           NaN
#                          Grenada  Americas       11137.0
#                           Serbia    Europe       10849.0
#                Equatorial Guinea    Africa        9777.0
#                           Brazil  Americas        9673.0
# Saint Vincent and the Grenadines  Americas        9359.0
#                            Gabon    Africa        9294.0
#                         Dominica  Americas        9144.0
#           Bosnia and Herzegovina    Europe        8223.0
#                         Thailand      Asia        8181.0
#                          Armenia      Asia        8007.0
#                          Belarus    Europe        7944.0
#                             Peru  Americas        7772.0
#                          Georgia      Asia        7600.0
#                  North Macedonia    Europe        7384.0
#                         Botswana    Africa        7270.0
#                          Albania    Europe        7058.0
#                           Belize  Americas        7017.0
#                            Libya    Africa        6763.0
#                       Azerbaijan      Asia        6757.0
#                          Ecuador  Americas        6642.0
#                     South Africa    Africa        6485.0
#                         Colombia  Americas        6417.0
#                          Moldova    Europe        6342.0
#                          Jamaica  Americas        6282.0
#                             Iraq      Asia        6180.0
#                           Tuvalu   Oceania        6007.0
#                             Fiji   Oceania        5887.0
#                         Paraguay  Americas        5667.0
#                           Kosovo    Europe        5641.0
#                         Suriname  Americas        5556.0
#                            Tonga   Oceania        5421.0
#                        Guatemala  Americas        5358.0
#                      El Salvador  Americas        5308.0
#                 Marshall Islands   Oceania        5164.0
#                          Namibia    Africa        5100.0
#                           Jordan      Asia        5048.0
#                        Indonesia      Asia        5016.0
#                         Mongolia      Asia        4814.0
#                          Ukraine    Europe        4654.0
#                          Algeria    Africa        4481.0
#                          Vietnam      Asia        4475.0
#                            Samoa   Oceania        4436.0
#                       Micronesia   Oceania        4336.0
#                       Cape Verde    Africa        4278.0
#                             Iran      Asia        4251.0
#                         Eswatini    Africa        4146.0
#                          Lebanon      Asia        3589.0
#                          Tunisia    Africa        4071.0
#                      Philippines      Asia        3905.0
#                         Djibouti    Africa        3802.0
#                          Bolivia  Americas        3800.0
#                          Morocco    Africa        3748.0
#                            Egypt    Africa        3644.0
#                        Venezuela  Americas        3640.0
#                 Papua New Guinea   Oceania        3517.0
#                        Palestine      Asia        3506.0
#                           Bhutan      Asia        3497.0
#                        Sri Lanka      Asia        3362.0
#                         Honduras  Americas        3278.0
#                           Angola    Africa        3204.0
#                          Vanuatu   Oceania        3188.0
#         SÃ£o TomÃ© and PrÃ­ncipe    Africa        2695.0
#                      Ivory Coast    Africa        2646.0
#                            India      Asia        2601.0
#                        Nicaragua  Americas        2589.0
#                            Congo    Africa        2584.0
#                       Uzbekistan      Asia        2563.0
#                       Mauritania    Africa        2475.0
#                       Bangladesh      Asia        2469.0
#                  Solomon Islands   Oceania        2299.0
#                          Nigeria    Africa        2280.0
#                            Kenya    Africa        2269.0
#                            Haiti  Americas        2173.0
#                            Ghana    Africa        2024.0
#                         Kiribati   Oceania        1989.0
#                         Cambodia      Asia        1896.0
#                             Laos      Asia        1858.0
#                         Zimbabwe    Africa        1851.0
#                       Kyrgyzstan      Asia        1736.0
#                          Senegal    Africa        1719.0
#                         Cameroon    Africa        1699.0
#                         Pakistan      Asia        1658.0
#                           Guinea    Africa        1549.0
#                         Ethiopia    Africa        1475.0
#                      Timor-Leste      Asia        1425.0
#                           Zambia    Africa        1423.0
#                            Benin    Africa        1390.0
#                            Nepal      Asia        1377.0
#                          Comoros    Africa        1360.0
#                         Tanzania    Africa        1348.0
#                       Tajikistan      Asia        1277.0
#                         Zanzibar    Africa           NaN
#                          Lesotho    Africa        1208.0
#                          Myanmar      Asia        1180.0
#                           Uganda    Africa        1105.0
#                             Togo    Africa         990.0
#                            Sudan    Africa         975.0
#                    Guinea-Bissau    Africa         974.0
#                           Rwanda    Africa         970.0
#                            Syria      Asia           NaN
#                     Burkina Faso    Africa         900.0
#                             Mali    Africa         889.0
#                           Gambia    Africa         861.0
#                          Liberia    Africa         805.0
#                          Eritrea    Africa         715.0
#                         DR Congo    Africa         695.0
#                             Chad    Africa         667.0
#                      North Korea      Asia           NaN
#                            Niger    Africa         613.0
#                       Mozambique    Africa         587.0
#                            Yemen      Asia         573.0
#                          Somalia    Africa         544.0
#                       Madagascar    Africa         536.0
#         Central African Republic    Africa         534.0
#                           Malawi    Africa         496.0
#                      South Sudan    Africa         467.0
#                     Sierra Leone    Africa         415.0
#                      Afghanistan      Asia         611.0
#                          Burundi    Africa         249.0

# %%
# Calculate the average of 'Worldbank_Estimate' and 'UN_Estimate' columns
avg_worldbank_un = df[['WorldBank_Estimate', 'UN_Estimate']].mean(axis=1)

# Display the results
print(avg_worldbank_un)
# Out:
# 1      234316.5
# 2      163507.5
# 3      133667.5
# 4      100640.5
# 5      113371.5
#          ...
# 219       624.0
# 220       736.0
# 221       492.5
# 222       371.0
# 223       266.5
# Length: 223, dtype: float64

# %%
# Fill the null values in 'imf' column with the calculated average
df['IMF_Estimate'] = df['IMF_Estimate'].fillna(avg_worldbank_un)

# Display the results
print(df[['Country/Territory', 'UN_Region', 'IMF_Estimate']].to_string(index=False))

# %%
# Drop the temporary 'avg_worldbank_un' column if not needed

# %% [markdown]
# [Visit this link to learn more about ffill](https://www.w3schools.com/python/pandas/ref_df_ffill.asp)

# %% [markdown]
# [Visit this link to learn more about bfill](https://www.w3schools.com/python/pandas/ref_df_bfill.asp)

# %% [markdown]
# ## Checking Missing Values

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Histogram

# %%
df.hist(figsize=(10,8))
plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=5, figsize=(12,9))

plt.show()

# %%
df["WorldBank_Estimate"].agg(["min","max"])

# %%
234316/5
#1 bin size if bins=5

# %%
df[df["WorldBank_Estimate"]<=46863.2]["WorldBank_Estimate"].count()

# %%
234316/10
#1 bin size if bins not given any number

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=3, figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=15, figsize=(15,12))

#23400/15 = 15300
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))
sns.heatmap(corr)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, fmt=".2f", cmap = 'GnBu', annot_kws={"size": 12})

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.title("Correlation Map")


plt.show()

# %%
corr = df.select_dtypes(include=[int, float]).corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.show()

# %% [markdown]
# ### Bar plot

# %%
df.head()

# %%
sns.barplot(x="UN_Region", y="WorldBank_Estimate", data=df, errorbar=None)

plt.show()

# %%
sns.barplot(x="WorldBank_Estimate", y="UN_Region", data=df, errorbar=None)

plt.show()

# %%
fig = plt.figure(figsize = (8,5))

ax = sns.barplot(x = "IMF_Estimate",  y = "UN_Region",
data = df, errorbar = None)

ax.bar_label(ax.containers[0])

plt.show()

# %%
fig = plt.figure(figsize = (8,5))
ax = sns.barplot(x = "UN_Region",  y = "IMF_Estimate",
                 data = df, errorbar = None)

ax.bar_label(ax.containers[0])


ax.set_title("Regions by IMF Estimate")
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
df.plot(x='UN_Region', y='UN_Estimate', kind='scatter',
        figsize=(10,6),
        title="Scatter Plot")

plt.show()

# %% [markdown]
# ### Boxplot and Outliers

# %% [markdown]
# ![image.png](attachment:da6a7715-3b1c-4165-a2a9-4dc8ca096bd7.png)

# %%
sns.boxplot(x=df["UN_Estimate"])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-35-992537101.py in <cell line: 0>()
# ----> 1 sns.boxplot(x=df["UN_Estimate"])
#       2
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
df[df["UN_Estimate"]>50000].head()

# %%
sns.boxplot(x=df["WorldBank_Estimate"])

plt.show()

# %%
sns.boxplot(x=df["IMF_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>100000]

# %%
df.UN_Estimate.mean()

# %%
df.shape

# %% [markdown]
# ## Create another dataframe called data excluding  5 countries with highest UN estimate

# %%
data = df[-(df["UN_Estimate"]>100000)]

# %%
data.head()

# %%
data.shape

# %%
data.UN_Estimate.mean()

# %%
df.UN_Estimate.mean()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x=data["UN_Estimate"])
plt.show()

# %% [markdown]
# ## Removing outliers

# %% [markdown]
# ![image.png](attachment:da6a7715-3b1c-4165-a2a9-4dc8ca096bd7.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lower_q = df["UN_Estimate"].quantile(0.25)
lower_q

# %%
higher_q = df["UN_Estimate"].quantile(0.75)
higher_q

# %%
iqr = higher_q - lower_q
iqr

# %%
upper_boundary = higher_q + 1.5 * iqr
upper_boundary

# %%
lower_boundary = lower_q - 1.5 * iqr
lower_boundary

# %%
df_filtered = df[(df["UN_Estimate"] < upper_boundary) & (df["UN_Estimate"] > lower_boundary)]

# %%
df_filtered.head()

# %%
df_filtered.shape
# there were 223 rows - 196 = 27 outliers dropped

# %%
df_filtered.UN_Estimate.mean()

# %%
df.UN_Estimate.mean()

# %%
#how can we create a table with following
df_filtered.WorldBank_Estimate.mean()

# %%
df.WorldBank_Estimate.mean()

# %%
df_filtered.IMF_Estimate.mean()

# %%
df.IMF_Estimate.mean()
